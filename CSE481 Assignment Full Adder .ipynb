# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit import *
from qiskit import QuantumCircuit, execute, transpile, Aer, IBMQ
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator

# Loading your IBM Quantum account(s)
provider = IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2022-09-02 23:13:07,034: Credentials are already in use. The existing account in the session will be replaced.

# %%
qc = QuantumCircuit(4,2)

# Preparing inputs
qc.x([0,1,2]) # Comment this line to make Qbit0 = |0>
qc.draw()

# %%
qc.ccx(0,1,3)
qc.draw()

# %%
qc.cx(0,1)
qc.draw()

# %%
qc.ccx(1,2,3)
qc.draw()

# %%
qc.cx(1,2)
qc.draw()

# %%
qc.cx(0,1)
qc.draw()

# %%
qc.measure(2,0) # extract XOR value
qc.measure(3,1)

# %%
qc.draw()

# %%
counts = execute(qc,Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(counts)

# %%
backend = provider.get_backend('ibm_oslo')

# %%
qc2 = transpile(qc,backend)
qc2.draw()

# %%
ans = backend.run(qc2,shots=800) # run in real quantum computer 800 times
counts = ans.result().get_counts()

# %%
plot_histogram(counts)
